# %%
import ee
import pandas as pd
import folium
import geehydro
from IPython.display import Image

# %%
ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=lf2oLclvFc447yEoe006uetp1ubMucVSQn01UZgprsU&tc=ydlhhFLXgi4WUJnLVAN5Sfl7TfiSwsZbTqOclr2yyq8&cc=l3ciKDCp-uCBEtRpLLLgAeABGQvupP94C6DqGVe6zWE>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=lf2oLclvFc447yEoe006uetp1ubMucVSQn01UZgprsU&tc=ydlhhFLXgi4WUJnLVAN5Sfl7TfiSwsZbTqOclr2yyq8&cc=l3ciKDCp-uCBEtRpLLLgAeABGQvupP94C6DqGVe6zWE</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %%
lat = 51.266389
lng = 19.330556

coords = [lat, lng]
Map = folium.Map(location=coords, zoom_start=6)

worldmap = ee.FeatureCollection("USDOS/LSIB_SIMPLE/2017")
location_filter = ee.Filter.eq("country_na","Ukraine")
country = worldmap.filter(location_filter)

dataset = ee.ImageCollection("COPERNICUS/S5P/NRTI/L3_NO2")
dataset = dataset.select('tropospheric_NO2_column_number_density')

date_filter = ee.Filter.date('2022-01-01', '2022-06-01')
dataset = dataset.filter(date_filter)

dataset = dataset.mean().clip(country)

visualisation_params = {
  "min": 0.00,
  "max": 0.00008,
  "palette": ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}

Map.setCenter(lat, lng, 6)
Map.addLayer(country)
Map.centerObject(country, 6)
Map.addLayer(dataset, visualisation_params, 'S5P HCHO')

folium.Marker(
    location=[lat, lng],
    popup="Coal Power Plant",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(Map)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_057a2132099879e50ca703bdb072a6c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_057a2132099879e50ca703bdb072a6c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_057a2132099879e50ca703bdb072a6c9 = L.map(
#                 &quot;map_057a2132099879e50ca703bdb072a6c9&quot;,
#                 {
#                     center: [51.266389, 19.330556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8232a88d55a8042fc9c0aaef38db9e23 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_057a2132099879e50ca703bdb072a6c9);
#
#
#             map_057a2132099879e50ca703bdb072a6c9.fitBounds(
#                 [[19.330556, 51.266389], [19.330556, 51.266389]],
#                 {&quot;maxZoom&quot;: 6}
#             );
#
#
#             var tile_layer_b69965de55559c4ce4ad7c43a550b386 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/65ab29f8e8da470794c6e9e88137dbd5-c7171e0e9c839c66e7704ce707c32081/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_057a2132099879e50ca703bdb072a6c9);
#
#
#             map_057a2132099879e50ca703bdb072a6c9.fitBounds(
#                 [[49.04444769364695, 31.471702064055535], [49.04444769364695, 31.471702064055535]],
#                 {&quot;maxZoom&quot;: 6}
#             );
#
#
#             var tile_layer_65663a274d8f92287c865291d67b2d46 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/5e73bf7991ade9262160f771df3a29cc-f592988cc331d4a51a70ed48098506fc/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_057a2132099879e50ca703bdb072a6c9);
#
#
#             var marker_df31c8124b34d12e5d209977ba1e179d = L.marker(
#                 [51.266389, 19.330556],
#                 {}
#             ).addTo(map_057a2132099879e50ca703bdb072a6c9);
#
#
#             var icon_24639d8116c604838e6391e38ed33aec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_df31c8124b34d12e5d209977ba1e179d.setIcon(icon_24639d8116c604838e6391e38ed33aec);
#
#
#         var popup_00c90425dc266e23b81d429093e1104c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_808102c609da5ed53fbe498324b699b1 = $(`&lt;div id=&quot;html_808102c609da5ed53fbe498324b699b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coal Power Plant&lt;/div&gt;`)[0];
#             popup_00c90425dc266e23b81d429093e1104c.setContent(html_808102c609da5ed53fbe498324b699b1);
#
#
#         marker_df31c8124b34d12e5d209977ba1e179d.bindPopup(popup_00c90425dc266e23b81d429093e1104c)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lat = 51.266389
lng = 19.330556

coords = [lat, lng]
Map = folium.Map(location=coords, zoom_start=6)

worldmap = ee.FeatureCollection("USDOS/LSIB_SIMPLE/2017")
location_filter = ee.Filter.eq("country_na","Ukraine")
country = worldmap.filter(location_filter)

dataset = ee.ImageCollection("COPERNICUS/S5P/NRTI/L3_NO2")
dataset = dataset.select('tropospheric_NO2_column_number_density')

date_filter = ee.Filter.date('2021-01-01', '2021-06-01')
dataset = dataset.filter(date_filter)

dataset = dataset.mean().clip(country)

visualisation_params = {
  "min": 0.00,
  "max": 0.00008,
  "palette": ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}

Map.setCenter(lat, lng, 6)
Map.addLayer(country)
Map.centerObject(country, 6)
Map.addLayer(dataset, visualisation_params, 'S5P HCHO')

folium.Marker(
    location=[lat, lng],
    popup="Coal Power Plant",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(Map)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9f3c457c4bb7b53484ccd414c19d59d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9f3c457c4bb7b53484ccd414c19d59d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a9f3c457c4bb7b53484ccd414c19d59d = L.map(
#                 &quot;map_a9f3c457c4bb7b53484ccd414c19d59d&quot;,
#                 {
#                     center: [51.266389, 19.330556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5836b92624f43ae42ad908144fe37f21 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9f3c457c4bb7b53484ccd414c19d59d);
#
#
#             map_a9f3c457c4bb7b53484ccd414c19d59d.fitBounds(
#                 [[19.330556, 51.266389], [19.330556, 51.266389]],
#                 {&quot;maxZoom&quot;: 6}
#             );
#
#
#             var tile_layer_f1eea9dd873d0880c09aadf80e8db7f0 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/65ab29f8e8da470794c6e9e88137dbd5-ca7e33d1b5cdd041f1c9641d206e3756/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9f3c457c4bb7b53484ccd414c19d59d);
#
#
#             map_a9f3c457c4bb7b53484ccd414c19d59d.fitBounds(
#                 [[49.04444769364695, 31.471702064055535], [49.04444769364695, 31.471702064055535]],
#                 {&quot;maxZoom&quot;: 6}
#             );
#
#
#             var tile_layer_5f3f7a7c365f3d0fd9a496d1dbf3cf24 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/739e1c95987da12529c92b2f5bcc3067-cc3d2d59c5d123a8201114761c7e6c1b/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9f3c457c4bb7b53484ccd414c19d59d);
#
#
#             var marker_e48bd93628604424ee987d2b98fc6ed3 = L.marker(
#                 [51.266389, 19.330556],
#                 {}
#             ).addTo(map_a9f3c457c4bb7b53484ccd414c19d59d);
#
#
#             var icon_b1695f97cef4d51485fd983da4062d99 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e48bd93628604424ee987d2b98fc6ed3.setIcon(icon_b1695f97cef4d51485fd983da4062d99);
#
#
#         var popup_484f11ad2c802fb473585d4f87141d9b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_60b749d92e6c6c2bc5ce107f33515542 = $(`&lt;div id=&quot;html_60b749d92e6c6c2bc5ce107f33515542&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coal Power Plant&lt;/div&gt;`)[0];
#             popup_484f11ad2c802fb473585d4f87141d9b.setContent(html_60b749d92e6c6c2bc5ce107f33515542);
#
#
#         marker_e48bd93628604424ee987d2b98fc6ed3.bindPopup(popup_484f11ad2c802fb473585d4f87141d9b)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
coords = [52.15, 10.33]  # [lat, long]
Map = folium.Map(location=coords, zoom_start=15)

worldmap = ee.FeatureCollection("USDOS/LSIB_SIMPLE/2017")
location_filter = ee.Filter.eq("country_na","Germany")
country = worldmap.filter(location_filter)

dataset = ee.ImageCollection("COPERNICUS/S5P/NRTI/L3_NO2")
dataset = dataset.select('tropospheric_NO2_column_number_density')

date_filter = ee.Filter.date('2021-10-01', '2021-12-01')
dataset = dataset.filter(date_filter)

dataset = dataset.mean().clip(country)

visualisation_params = {
  "min": 0.00,
  "max": 0.0002,
  "palette": ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}

Map.setCenter(10.451526, 51.165691, 15)
Map.addLayer(country)
Map.centerObject(country, 6)
Map.addLayer(dataset, visualisation_params, 'S5P HCHO')

folium.Marker(
    location=[52.524335, 13.523009],
    popup="Coal Power Plant",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(Map)
Map

# %%
lat = 51.266389
lng = 19.330556

coords = [lat, lng]
Map = folium.Map(location=coords, zoom_start=10)

square = ee.Geometry.BBox(lng-0.3, lat-0.2, lng+0.3, lat+0.2)

dataset = ee.ImageCollection("COPERNICUS/S5P/NRTI/L3_NO2")
dataset = dataset.select('tropospheric_NO2_column_number_density')

date_filter = ee.Filter.date('2021-10-01', '2021-12-01')
dataset = dataset.filter(date_filter)

dataset = dataset.mean().clip(square)

visualisation_params = {
  "min": 0.00,
  "max": 0.0001,
  "palette": ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}

Map.addLayer(square)
Map.addLayer(dataset, visualisation_params)

folium.Marker(
    location=[lat, lng],
    popup="Coal Power Plant",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(Map)

Map

# %%
lat = 49.514014
lng = 8.421459

coords = [lat, lng]
Map = folium.Map(location=coords, zoom_start=10)

square = ee.Geometry.BBox(lng-0.15, lat-0.1, lng+0.15, lat+0.1)

outer_square = ee.Geometry.BBox(lng-0.15*math.sqrt(2), lat-0.1*math.sqrt(2), lng+0.15*math.sqrt(2), lat+0.1*math.sqrt(2))


dataset = ee.ImageCollection("COPERNICUS/S5P/NRTI/L3_NO2")
dataset = dataset.select('tropospheric_NO2_column_number_density')

date_filter = ee.Filter.date('2019-01-01', '2019-07-01')
dataset = dataset.filter(date_filter)

dataset = dataset.sum().clip(square)

visualisation_params = {
  "min": 0.005,
  "max": 0.015,
  "palette": ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}

Map.addLayer(square)
Map.addLayer(outer_square)
Map.addLayer(dataset, visualisation_params)

folium.Marker(
    location=[lat, lng],
    popup="Coal Power Plant",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(Map)

Map

# %%
lat = 23.782990
lng = 120.192958

#lat = 49.514014
#lng = 8.421459

coords = [lat, lng]
Map = folium.Map(location=coords, zoom_start=10)

square = ee.Geometry.BBox(lng-0.15, lat-0.1, lng+0.15, lat+0.1)

outer_square = ee.Geometry.BBox(lng-0.15*math.sqrt(2), lat-0.1*math.sqrt(2), lng+0.15*math.sqrt(2), lat+0.1*math.sqrt(2))


dataset = ee.ImageCollection("COPERNICUS/S5P/NRTI/L3_NO2")
dataset = dataset.select('tropospheric_NO2_column_number_density')

date_filter = ee.Filter.date('2019-11-01', '2021-12-01')
dataset = dataset.filter(date_filter)

dataset = dataset.sum().clip(outer_square)

visualisation_params = {
  "min": 0.01,
  "max": 0.04,
  "palette": ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}

Map.addLayer(square)
Map.addLayer(outer_square)
Map.addLayer(dataset, visualisation_params)

folium.Marker(
    location=[lat, lng],
    popup="Coal Power Plant",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(Map)

Map
